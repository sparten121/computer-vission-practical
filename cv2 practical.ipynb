# %% [markdown]
# <a href="https://colab.research.google.com/github/sparten121/computer-vission-practical/blob/master/cv2%20practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICAL NO.  3

# %%
from google.colab.patches import cv2_imshow

# %%
 import cv2

# %%
originalImage = cv2.imread('/content/foxinleaves.jpg')

# %%
grayImage = cv2.cvtColor(originalImage, cv2.COLOR_BGR2GRAY)

# %%
blueImage=cv2.cvtColor(originalImage, cv2.COLOR_RGB2BGR)

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 127, 255, cv2.THRESH_BINARY)

# %%
 cv2_imshow(originalImage)
# Out:
# <PIL.Image.Image image mode=RGB size=500x357 at 0x7FBA1F6D8588>

# %%
 
cv2_imshow( grayImage)
cv2_imshow( blackAndWhiteImage)
cv2_imshow(blueImage)
# Out:
# <PIL.Image.Image image mode=L size=500x357 at 0x7FBA1F6D86D8>
# <PIL.Image.Image image mode=L size=500x357 at 0x7FBA1F6D8828>
# <PIL.Image.Image image mode=RGB size=500x357 at 0x7FBA1F6D8898>

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# PRACTICAL NO. 4

# %%
import cv2
image = cv2.imread('/content/13699.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800 at 0x7FBA1B260D30>

# %%
faceCascade = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.3,
    minNeighbors=4,
    minSize=(50,50)
)

# %%
print("[INFO] Found {0} Faces.".format(len(faces)))
# Out:
# [INFO] Found 8 Faces.

# %%
#for (x, y, w, h) in faces:
#   cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
#   roi_color = image[y:y + h, x:x + w]
#   print("[INFO] Object found. Saving locally.")
#   cv2.imwrite(str(w) + str(h) + '_faces.jpg', roi_color)

#status = cv2.imwrite('faces_detected.jpg', image)

# %% [markdown]
# PRACTICAL NO. 5

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/th.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=149x106 at 0x7FBA1B27B4A8>

# %%
height, width, _ = img.shape

# %%
for i in range(0,height-1):
  for j in range(0,width-1):
    pix=img[i,j]
    pix[0]=255-pix[0]
    pix[1]=255-pix[1]
    pix[2]=255-pix[2]
    img[i,j]=pix
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=149x106 at 0x7FBA1B278748>
